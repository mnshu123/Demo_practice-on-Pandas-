# %% [markdown]
# # How to handle No Header Column Excel Dataset :-

# %%
import pandas as pd

# %%
data=pd.read_excel("C:\\Users\\rahul\\OneDrive\\Desktop\\DA Project\\dataset\\demo.xlsx")

# %%
data
# Out:
#   Unnamed: 0  Unnamed: 1
# 0        NaN         NaN
# 1       ravi        34.0
# 2       john        45.0
# 3      rahul        56.0
# 4     qwerty        56.0
# 5        abc        31.0
# 6        kbc        12.0

# %%
data.shape
# Out:
# (7, 2)

# %%
data=pd.read_excel("C:\\Users\\rahul\\OneDrive\\Desktop\\DA Project\\dataset\\demo.xlsx",header=None,skiprows=2,names=['Name','Age'])
data
# Out:
#      Name  Age
# 0    ravi   34
# 1    john   45
# 2   rahul   56
# 3  qwerty   56
# 4     abc   31
# 5     kbc   12

# %%
data.to_excel("C:/Users/rahul/OneDrive/Desktop/DA Project/dataset/New_demo.xlsx",index=False)
